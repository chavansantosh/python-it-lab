# %% [markdown]
# # pandas

# %%
# pandas is a data manipulation library:
import pandas as pd

# %%
# method 1 : DataFrame : convert the dict / json/array/ so on ...data  into dataFrame

# %%
import pandas as pd
dicts = { "name" :["santosh","sumit","pari"],
          "age"  :[21,54,32] ,
          "Gender" :["male","male","female"]
}
dicts
# Out:
# {'name': ['santosh', 'sumit', 'pari'],
#  'age': [21, 54, 32],
#  'Gender': ['male', 'male', 'female']}

# %%
df = pd.DataFrame(dicts)
df
# Out:
#       name  age  Gender
# 0  santosh   21    male
# 1    sumit   54    male
# 2     pari   32  female

# %%
list1 = (1,2,3,4,5)

list1_df = pd.DataFrame(list1,columns = ["numbers"])
list1_df
# Out:
#    numbers
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5

# %%
# method 2: read_csv : load the datasat
pd.read_csv("C:\\Users\\MY PC\\Downloads\\dataset.csv")
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %% [markdown]
# # method 3: Head() display top 5 rows

# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\MY PC\\Downloads\\dataset.csv")

# %%
df.tail()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0

# %%
df.sample()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 223   56    0   0       200   288    1        0      133      1      4.0
#
#      slope  ca  thal  target
# 223      0   2     3       0

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
# shape 6 : check the shape
df.shape
# Out:
# (303, 14)

# %%
# method 7: info(): check the information 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# method 8: columns : check the culumns name in data set:
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
# method 9: dtypes : check the all data types:
df.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
# method 10 : isnull() check the missing value:
df.isnull() # false means value is present
# Out:
#        age    sex     cp  trestbps   chol    fbs  restecg  thalach  exang  \
# 0    False  False  False     False  False  False    False    False  False
# 1    False  False  False     False  False  False    False    False  False
# 2    False  False  False     False  False  False    False    False  False
# 3    False  False  False     False  False  False    False    False  False
# 4    False  False  False     False  False  False    False    False  False
# ..     ...    ...    ...       ...    ...    ...      ...      ...    ...
# 298  False  False  False     False  False  False    False    False  False
# 299  False  False  False     False  False  False    False    False  False
# 300  False  False  False     False  False  False    False    False  False
# 301  False  False  False     False  False  False    False    False  False
# 302  False  False  False     False  False  False    False    False  False
#
#      oldpeak  slope     ca   thal  target
# ...

# %%
df.isnull().sum() # for count
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
# method 11; isna() : check the missing value:
df.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
# method 12: single column
A = df["age"]
A
# Out:
# 0      63
# 1      37
# 2      41
# 3      56
# 4      57
#        ..
# 298    57
# 299    45
# 300    68
# 301    57
# 302    57
# Name: age, Length: 303, dtype: int64

# %%
# method 12: select the multiple columns:
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
# method 13: select_dtype : select specific type of value
int_column =df.select_dtypes(include = ["int"]).columns
int_column
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
# method 14 : describe()
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
# method 15: drop() : drop the columns

df.drop("target",axis = 1)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal
# 0        0   0     1
# 1        0   0     2
# 2        2   0     2
# ...

# %%
# method 16: duplicated() : check the duplicate rows
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 298    False
# 299    False
# 300    False
# 301    False
# 302    False
# Length: 303, dtype: bool

# %%
# method 17 : drop_duplicates()
df.drop_duplicates(inplace = True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# method 18 : value_count(): # 
df["target"].value_counts(dropna = True)
# Out:
# target
# 1    164
# 0    138
# Name: count, dtype: int64

# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\MY PC\\Downloads\\dataset.csv")

# %% [markdown]
# # Renaming and type convertion

# %%
df.rename(columns = {"target":"Result","sex":"Gender"})
# Out:
#      age  Gender  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63       1   3       145   233    1        0      150      0      2.3
# 1     37       1   2       130   250    0        1      187      0      3.5
# 2     41       0   1       130   204    0        0      172      0      1.4
# 3     56       1   1       120   236    0        1      178      0      0.8
# 4     57       0   0       120   354    0        1      163      1      0.6
# ..   ...     ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57       0   0       140   241    0        1      123      1      0.2
# 299   45       1   3       110   264    0        1      132      0      1.2
# 300   68       1   0       144   193    1        1      141      0      3.4
# 301   57       1   0       130   131    0        1      115      1      1.2
# 302   57       0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  Result
# ...

# %%
df.rename(index ={0:"first",1:"2nd"})
# Out:
#        age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# first   63    1   3       145   233    1        0      150      0      2.3
# 2nd     37    1   2       130   250    0        1      187      0      3.5
# 2       41    0   1       130   204    0        0      172      0      1.4
# 3       56    1   1       120   236    0        1      178      0      0.8
# 4       57    0   0       120   354    0        1      163      1      0.6
# ...    ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298     57    0   0       140   241    0        1      123      1      0.2
# 299     45    1   3       110   264    0        1      132      0      1.2
# 300     68    1   0       144   193    1        1      141      0      3.4
# 301     57    1   0       130   131    0        1      115      1      1.2
# 302     57    0   1       130   236    0        0      174      0      0.0
#
#        slope  ca  thal  target
# first      0   0     1       1
# ...

# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\MY PC\\Downloads\\dataset.csv")
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
df.columns = [col.title() for col in df.columns]

# %%
# Dataframe:
import numpy as np
dicts1 = {"Age":[10,25,84,np.nan,45,87,65,np.nan,8,6,np.nan]}
df = pd.DataFrame(dicts1)
df.head()
# Out:
#     Age
# 0  10.0
# 1  25.0
# 2  84.0
# 3   NaN
# 4  45.0

# %%
# method 22 : fillna(): fill the mising value:
df['Age'].fillna('unknow',inplace = True)
df
# Out:
# C:\Users\MY PC\AppData\Local\Temp\ipykernel_18800\1267410873.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna('unknow',inplace = True)
# C:\Users\MY PC\AppData\Local\Temp\ipykernel_18800\1267410873.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'unknow' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df['Age'].fillna('unknow',inplace = True)
#        Age
# ...

# %%
dicts1 = {"Age":[10,25,84,np.nan,45,87,65,np.nan,8,6,np.nan]}
df = pd.DataFrame(dicts1)

# %%
age_mean = int(df['Age'].mean())
age_mean

# %% [markdown]
# # 7-8-2026

# %%
# Dataframe:
import numpy as np
dicts1 = {"Age":[10,25,84,np.nan,45,87,65,np.nan,8,6,np.nan]}
df = pd.DataFrame(dicts1)
df
# Out:
#      Age
# 0   10.0
# 1   25.0
# 2   84.0
# 3    NaN
# 4   45.0
# 5   87.0
# 6   65.0
# 7    NaN
# 8    8.0
# 9    6.0
# 10   NaN

# %%
df['Age'].fillna(method = "ffill",inplace = True)
df['Age']
# Out:
# C:\Users\MY PC\AppData\Local\Temp\ipykernel_16636\3158529233.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(method = "ffill",inplace = True)
# C:\Users\MY PC\AppData\Local\Temp\ipykernel_16636\3158529233.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Age'].fillna(method = "ffill",inplace = True)
# 0     10.0
# 1     25.0
# 2     84.0
# 3     84.0
# 4     45.0
# 5     87.0
# 6     65.0
# ...

# %%
df['Age'].fillna(method = "bfill",inplace = True)
df['Age']
# Out:
# C:\Users\MY PC\AppData\Local\Temp\ipykernel_16636\2417205434.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Age'].fillna(method = "bfill",inplace = True)
# 0     10.0
# 1     25.0
# 2     84.0
# 3     84.0
# 4     45.0
# 5     87.0
# 6     65.0
# 7     65.0
# 8      8.0
# 9      6.0
# 10     6.0
# Name: Age, dtype: float64

# %%
# 25. notnull(): check the ono missing value
df.notnull().sum()
# Out:
# Age    11
# dtype: int64

# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\MY PC\\OneDrive\\Desktop\\Bank_customer_churn.csv")
df.head(3)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1

# %%
# method 27: replace method() replace the with another value
df.replace({'Gender': {'Male': 1, 'Female': 0}}, inplace=True)

# %%
df['Gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
# sorting ()
# method 28: sort the column value
df.sort_values('Age',ascending = False)
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France       0   42
# 1          2    15647311      Hill          608     Spain       0   41
# 2          3    15619304      Onio          502    France       0   42
# 3          4    15701354      Boni          699    France       0   39
# 4          5    15737888  Mitchell          850     Spain       0   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
# method 29: sort()_index : sort the index:
df.sort_index(ascending = False)
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France       0   42
# 1          2    15647311      Hill          608     Spain       0   41
# 2          3    15619304      Onio          502    France       0   42
# 3          4    15701354      Boni          699    France       0   39
# 4          5    15737888  Mitchell          850     Spain       0   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %% [markdown]
# # Grouping and Aggregation

# %%
df.groupby("Gender")["Age"].mean()
# Out:
# Gender
# 0    39.238389
# 1    38.658237
# Name: Age, dtype: float64

# %%
df.groupby(["Geography","Gender"])["Age"].mean()
# Out:
# Geography  Gender
# France     0         38.773994
#            1         38.296404
# Germany    0         40.154233
#            1         39.424772
# Spain      0         39.199265
#            1         38.649135
# Name: Age, dtype: float64

# %%
df.groupby("Geography")["CreditScore"].mean()
# Out:
# Geography
# France     649.668329
# Germany    651.453567
# Spain      651.333872
# Name: CreditScore, dtype: float64

# %%
df["value_"["Older" if age > 45 else "Young" for age in df['Age']]
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France       0   42
# 1          2    15647311      Hill          608     Spain       0   41
# 2          3    15619304      Onio          502    France       0   42
# 3          4    15701354      Boni          699    France       0   39
# 4          5    15737888  Mitchell          850     Spain       0   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...
