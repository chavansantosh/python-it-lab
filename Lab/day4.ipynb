# %%
#1. Create a dictionary student with keys: "name", "age", "city" and print it.
text = {"name":"santosh","age":20,"city":"hyd"}
text
# Out:
# {'name': 'santosh', 'age': 20, 'city': 'hyd'}

# %%
#2. Given d = {"a": 1, "b": 2, "c": 3}, print all keys using keys() method.
dict1 = {"a": 1, "b": 2, "c": 3}
dict1
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
dict1.keys()
# Out:
# dict_keys(['a', 'b', 'c'])

# %%
#3. Given d = {"a": 1, "b": 2}, print all values using values() method.
d = {"a":1,"b":2}
print(d.values())
# Out:
# dict_values([1, 2])

# %%
#4. Use get() method to safely get the value of key "name" from dictionary
d = {"name": "Sumit", "age": 25}
print(d.get("name"))
# Out:
# Sumit

# %%
#5. Create a tuple with 5 numbers and print its type and length.
tuple1=(20,30,40,80,77)
tuple1
# Out:
# (20, 30, 40, 80, 77)

# %%
print(type(tuple1))
# Out:
# <class 'tuple'>

# %%
print(len(tuple1))
# Out:
# 5

# %%
#6. Create a tuple tup = (10, 20, 30, 40, 50) and use count() to count how
#many times 20 appears.
tup = (10, 20, 30, 40, 50) 
tup.count(20)
# Out:
# 1

# %%
#7. Use index() method on tuple (10, 20, 30, 40) to find the position of 30.
tuple2 =(10, 20, 30, 40)
tuple2.index(30)
# Out:
# 2

# %%
#8. Create an empty dictionary and add 3 key-value pairs using
#assignment.
my_dict = {}
my_dict["name"] = "Santosh"
my_dict["age"] = 25
my_dict["city"] = "Hyderabad"
print(my_dict)
# Out:
# {'name': 'Santosh', 'age': 25, 'city': 'Hyderabad'}

# %%
#9. Given d = {"a": 1, "b": 2}, use update() to add {"c": 3, "d": 4}.
d = {"a": 1,"b": 2}
d.update({"c": 3, "d": 4})
print(d)
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %%
#10. Remove the key "age" from dictionary using pop().
student = {"name": "Rahul","age": 22, "city": "Delhi"} 
student.pop("age")
# Out:
# 22

# %%
print(student)
# Out:
# {'name': 'Rahul', 'city': 'Delhi'}

# %%
#11.Use popitem() on dictionary d = {"x": 10, "y": 20, "z": 30} and print the
#removed item.
d = {"x": 10, "y": 20, "z": 30}
d.popitem()
# Out:
# ('z', 30)

# %%
#12. Create a copy of dictionary original = {"a": 1, "b": 2} using copy()
#method.
original = {"a": 1, "b": 2}
original
# Out:
# {'a': 1, 'b': 2}

# %%
print(original.copy())
# Out:
# {'a': 1, 'b': 2}

# %%
#13. Use fromkeys() to create a dictionary with keys ["red", "green","blue"] and default value 0.

# %%
keys = ["red", "green","blue"]
dict2 =dict.fromkeys(keys,"red")
print(dict2)
# Out:
# {'red': 'red', 'green': 'red', 'blue': 'red'}

# %%
#14.Create a tuple with mixed data types and try to change one element(show error).
tuple1 = (20,40,"s","c",20.5)
tuple1
# Out:
# (20, 40, 's', 'c', 20.5)

# %%
#15. Given d = {"name": "Sumit"}, use setdefault("age", 25) and print the dictionary.
d = {"name": "Sumit"}
d.setdefault("age", 25)
print(d)
# Out:
# {'name': 'Sumit', 'age': 25}

# %%
# 16. Create a dictionary. Add 3 items using update(), then remove the last
# inserted item using popitem().
d = {"name": "sumit"}
d.update({"age": 27})
d.update({"city": "hyd"})
d.update({"course": "Data Science"})
print(d)

d.popitem()
print(d)
# Out:
# {'name': 'sumit', 'age': 27, 'city': 'hyd', 'course': 'Data Science'}
# {'name': 'sumit', 'age': 27, 'city': 'hyd'}

# %%
# 17. Create a tuple of 6 numbers. Find the index of a number and count
#  how many times it appears.
number = (7,5,6,8,2,1)
print("index 7 :",number.index(7))
print("count 8 :",number.count(8))
# Out:
# index 7 : 0
# count 8 : 1

# %%
# 18. Take 3 student names and marks as input and store them in a
# dictionary (name as key, mark as value).
Std = {}
for i in range(3):
     name = input("student name")
     marks =int(input("marks"))
     Std[name]= marks

print(Std)
# Out:
# student name santosh
# marks 77
# student name sagar
# marks 65
# student name sumit
# marks 99
# {'santosh': 77, 'sagar': 65, 'sumit': 99}

# %%
# 19. Given data = {"a": 10, "b": 20, "c": 10}, use items() and print only
# keys where value is 10.
data = {"a": 10, "b": 20, "c": 10}

for key , value in data.items():
    if value == 10:
        print(key)
# Out:
# a
# c

# %%
# 20. Create a dictionary of 5 items, make a copy, clear the original
# dictionary, and show both.
data = {"a": 20,"b": 30,"c": 40,"d": 50,"e": 70}

A_data = data.copy()

data.clear()

print("original data",data)
print("copied data",A_data)
# Out:
# original data {}
# copied data {'a': 20, 'b': 30, 'c': 40, 'd': 50, 'e': 70}

# %%
# 21. (Hard) Create a dictionary student with 4 key-value pairs. Then use
# update() to add another dictionary, remove the last item using popitem(),
# and finally print all items using items().
student = {"name": "Santosh","age": 23,"course": "Data Science","marks": 85
}
new_data = {
    "city": "Hyderabad",
    "grade": "A"
}

student.update(new_data)

student.popitem()

print(student.items())
# Out:
# dict_items([('name', 'Santosh'), ('age', 23), ('course', 'Data Science'), ('marks', 85), ('city', 'Hyderabad')])
