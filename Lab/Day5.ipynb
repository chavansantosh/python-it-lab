# %%
# 1. (Easy) Create a set with numbers {1, 2, 3, 2, 4, 1} and print it. What do you observe?
numbers = {1,2,3,2,4,1}
print(numbers)
# Out:
# {1, 2, 3, 4}

# %%
# 2. Create an empty set using correct syntax and add 3 numbers using add().
a = set()
set
# Out:
# set

# %%
a.add(10)

# %%
a.add(20)

# %%
a.add(45)

# %%
print(a)
# Out:
# {10, 20, 45}

# %%
#3.Given s = {10, 20, 30}, add multiple elements [40, 50, 60] using update().
s = {10, 20, 30}
s.update([40,50,60])

# %%
print(s)
# Out:
# {40, 10, 50, 20, 60, 30}

# %%
#4.Remove element 20 from set s = {10, 20, 30, 40} using remove() and discard(). Show difference.
s = {10, 20, 30, 40}
s.remove(20)

# %%
s
# Out:
# {10, 30, 40}

# %%
s.discard("")

# %%
s
# Out:
# {10, 30, 40}

# %%
#5.Create two sets A = {1, 2, 3, 4} and B = {3, 4, 5, 6}. Print union,intersection, and difference.
A = {1, 2, 3, 4}
B = {3, 4, 5, 6}
A.union(B)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
A.intersection(B)
# Out:
# {3, 4}

# %%
A.difference(B)
# Out:
# {1, 2}

# %%
#6.Check if 25 is present in set s = {10, 20, 30, 40} using in keyword.
s = {10, 20, 30, 40}
print(25 in s)
# Out:
# False

# %%
#7 Create a set from the list [1, 2, 2, 3, 4, 4, 5] and print its length.
list1 =[1, 2, 2, 3, 4, 4, 5]
set1 = set(list1)
set1,len(set1)
# Out:
# ({1, 2, 3, 4, 5}, 5)

# %%
#8.Take 5 numbers as input from user, store them in a set, and print unique numbers only.
D = input("any five numbers")
# Out:
# any five numbers 4,5,2,1,3

# %%
D = set()

# %%
#9.Given two sets A = {1, 2, 3} and B = {3, 4, 5}, print elements that are in A but not in B.
A = {1, 2, 3}
B = {3, 4, 5}
A.difference(B)
# Out:
# {1, 2}

# %%
#10.Create a set and try to add a list [1,2,3] inside it. What happens?
A = set()
A.add([1,2,3])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 3
#       1 #10.Create a set and try to add a list [1,2,3] inside it. What happens?
#       2 A = set()
# ----> 3 A.add([1,2,3])
#
# TypeError: unhashable type: 'list'

# %%
#11.Take age as input. If age >= 18, print "You are eligible to vote".
age = int(input("please enter your age"))
if age <= 18:
 print("you are elligible to vote")
# Out:
# please enter your age 20

# %%
#12.Take a number and check if it is positive, negative, or zero using if-elif-else.
A =int(input("please enter your number"))
if A>= 0:
 print("positive")
elif A<=0 :
 print("negative")
else:
 print("zero")
# Out:
# please enter your number -5
# negative

# %%
#13.Take two numbers and print the larger one using if-else.
a=10
b=30
if a>b:
    print("larger number")
elif a<b:
    print("smaller number")
else:
    print("not small or large")
# Out:
# smaller number

# %%
#14.Take a character and check if it is a vowel (a, e, i, o, u) using if statement.
A = input("enter a character:")
vowels = ("a","e","i","o","u")
         
if A.lower() in vowels:
         print("its vowels")
    
         
else:
    print("not a vowels")
# Out:
# enter a character: d
# not a vowels

# %%
# 15.Take marks and print grade: ≥90 → A, ≥80 → B, ≥70 → C, else → Fail.
marks = 77
if marks >= 90:
    print("grade: A")
elif marks >=80:
    print("Grade B")
elif marks >= 70:
    print("Grade C")
else:
    print("Fail")
# Out:
# Grade C

# %%
# 16.Take three numbers and print the largest one using if-elif-else.
a = 77
b = 65
c = 99
if a > b and a > c:
    print("largest num is: a")
elif b > a and b > c:
    print("largest num is: b")
else:
    print("largest num is: c")
# Out:
# largest num is: c

# %%
# 17.Take a number and check if it is even and greater than 50.
num = 78
if num % 2 == 0 and num > 50:
    print("even and greater than 50")
else:
    print("num is not even and greater than 50")
# Out:
# even and greater than 50

# %%
# 18. (Hard) Take username and password. If username == "admin" and password ==
# "1234", print "Login Successful", else "Login Failed".
username = "admin"
password ="1234"
if username == "admin"  and password == "1234":
    print("Login succesfull")
else:
    print("login failed")
# Out:
# Login succesfull

# %%
# 19.Take a year as input and check if it is a leap year (divisible by 4 but not 100, or divisible by 400).
year =int(input("enter a year:"))
if year % 4 == 0 and year % 100 !=0:
    print("Leap year")
elif year % 400 == 0:
    print("Leap year")
else:
    print("Not a leap year")
# Out:
# enter a year: 2025
# Not a leap year

# %%
# 20.Take three sides of a triangle and check if they can form a valid triangle (sum of any two sides > third side
a =float(input("side 1: "))
b =float(input("side 2: "))
c =float(input("side 3: "))
if a + b > c and b + c > a and c + a > b:
    print("triangle")
else:
    print("invalid")
# Out:
# side 1:  5
# side 2:  7
# side 3:  8
# triangle

# %%
# 21.Take three numbers as input from the user. Print the largest number and also check whether all three numbers are equal or not.
a =int(input("num 1: "))
b =int(input("num 2: "))
c =int(input("num 3: ")) 
if a == b and b == c:
    print(" all three numbers are equal ")
elif a > b and a > c:
    print("largest num is a")
elif  b > a and b > c:
    print("largest num is b")
else:
    print("larghest num is c")
# Out:
# num 1:  54
# num 2:  62
# num 3:  21
# largest num is b

# %%
## 22.Take a year as input. Check if it is a leap year or not. (A year is leap if
# divisible by 4, but not by 100, unless also divisible by 400)
a =int(input("year 1: "))
b =int(input("year 2: "))
c =int(input("year 3: ")) 
if a % 4 ==0 and a % 100 != 0 or a % 400 == 0:
    print (a,"Leap year")
else:
     print(a,"Not a Leap year")
if b % 4 ==0 and b % 100 != 0 or b % 400 == 0:
    print (b,"Leap year")
else:
     print(b,"Not a Leap year")
if c % 4 ==0 and c % 100 != 0 or c % 400 == 0:
    print (c,"Leap year")  
else:
    print(c,"Not a Leap year")
# Out:
# year 1:  2024
# year 2:  2025
# year 3:  2028
# 2024 Leap year
# 2025 Not a Leap year
# 2028 Leap year
