# %%
# 1.Create a list named students with 5 student names and print it.
list=["ram","shyam","santosh","paritosh","kiran"]
print(list)

# %%
# 2.
numbers=[10,20,30,40,50]
print(numbers)

# %%
print("list:",numbers)
# Out:
# list: [10, 20, 30, 40, 50]

# %%
print("type:",type(numbers))
# Out:
# type: <class 'list'>

# %%
print("length:",len(numbers))
# Out:
# length: 5

# %%
# 3.Create an empty list and append 3 numbers into it using append().
name=[  ]
name.append(1)

# %%
print(name)
# Out:
# [1]

# %%
name.append(2)
print(name)
# Out:
# [1, 2]

# %%
name.append(3)
print(name)
# Out:
# [1, 2, 3]

# %%
# 4.Given lst = [1, 2, 3], use extend() to add [4, 5, 6] to it.
list=[1,2,3]
print(list)

# %%
list.extend("4")
print(list)
# Out:
# [1, 2, 3, '4', '4']

# %%
list.extend("5")
print(list)
# Out:
# [1, 2, 3, '4', '4', '5']

# %%
list.extend("6")
print(list)
# Out:
# [1, 2, 3, '4', '4', '5', '6', '6', '6']

# %%
# 5.Use insert() to add number 100 at index 2 in the list [10, 20, 30, 40].
list=[10,20,30,40]
list.index(30)

# %%
list.insert(2,100)

# %%
print(list)
# Out:
# [10, 20, 100, 30, 40]

# %%
# 6. Remove the element 50 from the list [10, 20, 50, 30, 50] using remove
list=[10,20,50,30,50]
print(list)
# Out:
# [10, 20, 50, 30, 50]

# %%
list.remove(50)

# %%
print(list)
# Out:
# [10, 20, 30, 50]

# %%
#7.Use pop() to remove the last element from lst = [5, 10, 15, 20] and primt the list
list=[5,10,15,20]
list
# Out:
# [5, 10, 15, 20]

# %%
list.pop(3)
# Out:
# 20

# %%
print(list)
# Out:
# [5, 10, 15]

# %%
#8.Clear all elements from the list data = [1, 2, 3, 4, 5] using clear()
list=[1, 2, 3, 4, 5]
list
# Out:
# [1, 2, 3, 4, 5]

# %%
list.clear()

# %%
print(list)
# Out:
# []

# %%
#9.Find the index of 25 in the list [10, 15, 25, 30, 40] using index().
list=[10,15,25,30,40]
list
# Out:
# [10, 15, 25, 30, 40]

# %%
list.index(25)
# Out:
# 2

# %%
#10. Count how many times 7 appears in the list [7, 2, 7, 5, 7, 8] using count()
list=[7,2,7,5,7,8]
list
# Out:
# [7, 2, 7, 5, 7, 8]

# %%
list.count(7)
# Out:
# 3

# %%
#11. Sort the list [45, 12, 78, 23, 56] in ascending order using sort().
list=[45, 12, 78, 23, 56]
list
# Out:
# [45, 12, 78, 23, 56]

# %%
list.sort(reverse=False)

# %%
print(list)
# Out:
# [12, 23, 45, 56, 78]

# %%
#12.Sort the list [45, 12, 78, 23, 56] in descending order.
list=[45, 12, 78, 23, 56]
list
# Out:
# [45, 12, 78, 23, 56]

# %%
list.sort(reverse=True)

# %%
print(list)
# Out:
# [78, 56, 45, 23, 12]

# %%
#13. Reverse the list fruits = ["apple", "banana", "mango", "orange"] using reverse()
fruits = ["apple", "banana", "mango", "orange"]
fruits
# Out:
# ['apple', 'banana', 'mango', 'orange']

# %%
fruits.reverse()

# %%
print(fruits)
# Out:
# ['orange', 'mango', 'banana', 'apple']

# %%
#14.Create a copy of list original = [1, 2, 3, 4] using copy() and print both.
original=[1, 2, 3, 4] 
original
# Out:
# [1, 2, 3, 4]

# %%
original.copy()
# Out:
# [1, 2, 3, 4]

# %%
# 15.Take a sentence from user (e.g. "I love Python programming") 
name="I love Python programming"
name
# Out:
# 'I love Python programming'

# %%
name.split()
# Out:
# ['I', 'love', 'Python', 'programming']

# %%
#16.Create a list of 5 numbers. Append 3 more numbers, then sort it in
#descending order
list=[20,30,40,70,80]
list
# Out:
# [20, 30, 40, 70, 80]

# %%
list.append(14)
list.append(55)
list.append(77)
print(list)
# Out:
# [20, 30, 40, 70, 80, 14, 55, 77]

# %%
list.sort(reverse=True)
print(list)
# Out:
# [80, 77, 70, 55, 40, 30, 20, 14]

# %%
#17. Create a list. Insert "Python" at index 0, then remove the last element
#using pop(), and print the length.
list1=["santosh","paritosh","nayan"]
list1.insert(0,"python")
list1
# Out:
# ['python', 'santosh', 'paritosh', 'nayan']

# %%
list1.pop(3)
# Out:
# 'nayan'

# %%
list1
# Out:
# ['python', 'santosh', 'paritosh']

# %%
#18. Take 5 city names as input from user and store them in a list. Then
#print them in reverse order.
name=list(input(city1,)
name
